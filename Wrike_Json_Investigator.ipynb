# %%
import pandas
import wrike_credentials as w_creds
import pprint as pp
import requests
import json

user_id = 'KUAFY5YK'

# %%
print(w_creds.client_id)
print(w_creds.client_secret)
# Out:
# PP1sS81B
# OkWea2umzOwTAnBJzn9PgD3IJRZjPcVGP3oZAWOhdoupWXknY2fGHb9jWWJmrPKo

# %%
#This has to be run to get the 'code'

url = "https://www.wrike.com/oauth2/authorize/v4?client_id="+w_creds.client_id+"&response_type=code"

print(url)
# Out:
# https://www.wrike.com/oauth2/authorize/v4?client_id=PP1sS81B&response_type=code

# %%
resp = requests.get(url)
resp.content
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, viewport-fit=cover">\n  <meta name="referrer" content="never">\n\n  <title>Wrike Login</title>\n\n  <link rel="canonical" href="/login/" />\n\n  <base href="/frontend/wrikelogin/">\n\n  <link href="https://fonts.googleapis.com/css?family=Open+Sans:300,400,400i,600,700,800&subset=cyrillic,greek" rel="stylesheet">\n\n        <style>\n        .app-loader {\n          display: none;\n        }\n      </style>\n    \n\n  <script defer src="/frontend/wrikelogin/1.40.0_1975095/assets/main.dart.js?time=2019-08-04 22:37:53.176200&version=1.40.0"></script>\n</head>\n\n<body>\n  <script>\n    function getCookie(name) {\n  const matches = document.cookie.match(new RegExp(\n    \'(?:^|; )\' + name.replace(/([\\.$?*|{}\\(\\)\\[\\]\\\\\\/\\+^])/g, \'\\\\$1\')\n    + \'=([^;]*)\'));\n  return matches ? decodeURIC
# ...

# %%
resp.url
# Out:
# 'https://www.wrike.com/login/'

# %%
#The code can only be called 1 time it seems
data = {
  'client_id': 'PP1sS81B',
  'client_secret': 'OkWea2umzOwTAnBJzn9PgD3IJRZjPcVGP3oZAWOhdoupWXknY2fGHb9jWWJmrPKo',
  'grant_type': 'authorization_code',
  'code': 'y1RuRoG1aymhOqInbAOVveTU1p9pwF9AwWQbL3Mrs15yDrYIguLewZAxYeZBeCd6-N'
}

response = requests.post('https://www.wrike.com/oauth2/token', data=data)

# %%
print(response.content)
# Out:
# b'{"access_token":"eyJ0dCI6InAiLCJhbGciOiJIUzI1NiIsInR2IjoiMSJ9.eyJkIjoie1wiYVwiOjI3NDQwODMsXCJpXCI6NjQ0MjA1MixcImNcIjo0NjEyNzE3LFwidlwiOlwiXCIsXCJ1XCI6NjA1OTc4NixcInJcIjpcIlVTXCIsXCJzXCI6W1wiTlwiXSxcInpcIjpbXSxcInRcIjoxNTY1MDM5MzM1MDAwfSIsImV4cCI6MTU2NTAzOTMzNSwiaWF0IjoxNTY1MDM1NzM1fQ.U8Zb5s-hEdgx0boS3xRxj4BoAFCzYT1TYjGSnNsJm-A","token_type":"bearer","host":"www.wrike.com","expires_in":3600,"refresh_token":"eyJ0dCI6InAiLCJhbGciOiJIUzI1NiIsInR2IjoiMSJ9.eyJkIjoie1wiYVwiOjI3NDQwODMsXCJpXCI6NjQ0MjA1MixcImNcIjo0NjEyNzE3LFwidlwiOlwiXCIsXCJ1XCI6NjA1OTc4NixcInJcIjpcIlVTXCIsXCJzXCI6W1wiTlwiXSxcInpcIjpbXCJyc2hcIl0sXCJ0XCI6MTU2NTAzOTMzNTAwMH0iLCJleHAiOjE1NjUwMzkzMzUsImlhdCI6MTU2NTAzNTczNX0.g7y4DpLuahlQ9kJUmYUMKiZ2cgDB_dElNgQqPHkQiY8"}'

# %%
#type(response.content)
dictionary = response.json()
access_token = dictionary['access_token']

# %%
#Now you can use the access_token to get anything.
headers = {
    'Authorization': 'bearer '+access_token,
}

params = (
    ('me', 'true'),
)

response2 = requests.get('https://www.wrike.com/api/v4/contacts', headers=headers, params=params)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('https://www.wrike.com/api/v4/contacts?me=true', headers=headers)

# %%
#Printing User Information, using params and url above
json.loads(response2.text)
# Out:
# {'kind': 'contacts',
#  'data': [{'id': 'KUAFY5YK',
#    'firstName': 'Garrett',
#    'lastName': 'Scott',
#    'type': 'Person',
#    'profiles': [{'accountId': 'IEACTXYT',
#      'email': 'garrettscott@mydealerworld.com',
#      'role': 'User',
#      'external': False,
#      'admin': False,
#      'owner': False}],
#    'avatarUrl': 'https://www.wrike.com/avatars//7C/C1/7QhBWnaduV8h.png',
#    'timezone': 'America/New_York',
#    'locale': 'en',
#    'deleted': False,
#    'me': True,
#    'title': 'Strategist'}]}

# %%
headers = {
    'Authorization': 'bearer '+access_token,
}

params = (
    #('createdDate', '{"start":"2019-05-21T10:45:51Z","end":"2019-06-23T10:45:51Z"}'),
    ('trackedDate', '{"start":"2019-05-21T13:45:51","end":"2019-06-23T13:45:51"}'),
)

tasks = requests.get('https://www.wrike.com/api/v4/contacts/KUAFY5YK/timelogs', headers=headers, params=params)

# %%
#Printing User Timelog Information, using params and url above
tasks.content
tasks_json = json.loads(tasks.text)
tasks_json
# Out:
# {'kind': 'timelogs',
#  'data': [{'id': 'IEACTXYTJQABVIIE',
#    'taskId': 'IEACTXYTKQKV7P7S',
#    'userId': 'KUAFY5YK',
#    'hours': 0.333333333333333,
#    'createdDate': '2019-06-21T18:35:59Z',
#    'updatedDate': '2019-06-21T18:35:59Z',
#    'trackedDate': '2019-06-21',
#    'comment': ''},
#   {'id': 'IEACTXYTJQABVH23',
#    'taskId': 'IEACTXYTKQKWACCG',
#    'userId': 'KUAFY5YK',
#    'hours': 0.503499166666667,
#    'createdDate': '2019-06-21T17:27:08Z',
#    'updatedDate': '2019-06-21T17:27:08Z',
#    'trackedDate': '2019-06-21',
#    'comment': ''},
#   {'id': 'IEACTXYTJQABVIID',
#    'taskId': 'IEACTXYTKQKWACCG',
#    'userId': 'KUAFY5YK',
#    'hours': 0.666666666666667,
#    'createdDate': '2019-06-21T18:35:47Z',
#    'updatedDate': '2019-06-21T18:35:47Z',
#    'trackedDate': '2019-06-21',
#    'comment': ''},
#   {'id': 'IEACTXYTJQABVFSF',
#    'taskId': 'IEACTXYTKQK3WSOS',
#    'userId': 'KUAFY5YK',
#    'hours': 0.666666666666667,
# ...

# %%
params= (('trackedDate','{"start":"2019-06-10"}'),)
foldertime = requests.get('https://www.wrike.com/api/v4/folders/347525602/timelogs?createdDate={"start":"2019-05-21T10:45:51Z","end":"2019-05-23T10:45:51Z"}&trackedDate={"equal":"2019-05-22"}', headers=headers)
            #requests.get('https://www.wrike.com/api/v4/folders/IEABQ4RUI4AQJFU3/timelogs', headers=headers, params=params)
json.loads(foldertime.text)
# Out:
# {'errorDescription': 'Invalid Folder ID', 'error': 'invalid_request'}

# %%
params = (('trackedDate', '{"equal":"2019-05-22"}'),)

folderstime = requests.get('https://www.wrike.com/api/v4/folders/IEACTXYTI4KTNDNG/timelogs', headers=headers, params=params)
json.loads(foldertime.text)
# Out:
# {'errorDescription': 'Invalid Folder ID', 'error': 'invalid_request'}

# %%
params = (
    ('createdDate', '{"start":"2019-05-21T10:45:51Z","end":"2019-06-23T10:45:51Z"}'),
    ('trackedDate', '{"equal":"2019-05-22"}'),
)

response = requests.get('https://www.wrike.com/api/v4/folders/IEACTXYTI4KTNDNG/timelogs', headers=headers, params=params)
json.loads(response.text)
# Out:
# {'errorDescription': 'Invalid Folder ID', 'error': 'invalid_request'}

# %%
params = (
    #('createdDate', '{"start":"2019-05-21T10:45:51Z","end":"2019-06-23T10:45:51Z"}'),
    #('trackedDate', '{"start":"2019-05-21T13:45:51","end":"2019-06-23T13:45:51"}'),
)

usertasks = requests.get('https://www.wrike.com/api/v4/tasks/IEACTXYTKQKWACCG,IEACTXYTKQK3WSOS', headers=headers, params=params)
json.loads(usertasks.text)
# Out:
# {'kind': 'tasks',
#  'data': [{'id': 'IEACTXYTKQKWACCG',
#    'accountId': 'IEACTXYT',
#    'title': 'Hawkinson Nissan Implementation',
#    'description': '<a href="mailto:jtuley&#64;hawkinsonnissankia.com"><span style="color: #1e88e5;">jtuley&#64;hawkinsonnissankia.com</span></a><br />',
#    'briefDescription': 'jtuley&#64;hawkinsonnissankia.com',
#    'parentIds': ['IEACTXYTI4KTNDNG',
#     'IEACTXYTI4KU7S3L',
#     'IEACTXYTI4KWABE6',
#     'IEACTXYTI4KWAB7X'],
#    'superParentIds': [],
#    'sharedIds': ['KX74IDC3',
#     'KUAFY5IP',
#     'KX74FUKH',
#     'KUAFVIMJ',
#     'KUAF3V6K',
#     'KUAFVUPC',
#     'KUAFVN7U',
#     'KX74ES7R',
#     'KUAFZCJB',
#     'KUAFY5YK',
#     'KUAFRCFD',
#     'KUAF6J4X',
#     'KUAFVILE',
#     'KUAFZECP',
#     'KUAFVILD',
#     'KUAFUZY6',
#     'KUAFZCGP'],
#    'responsibleIds': ['KUAFY5IP'],
#    'status': 'Active',
#    'importance': 'High',
#    'createdDate': '2019-05-31T18:16:11Z',
#    'updatedDate': '2019-08-02T14:11:55Z',
# ...

# %%
#Pretty sure I need more authorization
response = requests.get('https://wrike.com/api/v4/folders', headers=headers)
response.content
# Out:
# b'{"errorDescription":"Authorization method unknown","error":"not_authorized"}'
